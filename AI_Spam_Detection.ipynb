# %% [markdown]
# <a href="https://colab.research.google.com/github/Jawad-repo/Model_Traning_For_Spam_Detection/blob/main/AI_Spam_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=messages = pd.read_csv('SpamDataset.csv', names=["Category","Message"])
df.head()
# Out:
#    Category                                            Message
# 0  Category                                            Message
# 1       ham  Go until jurong point, crazy.. Available only ...
# 2       ham                      Ok lar... Joking wif u oni...
# 3      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4       ham  U dun say so early hor... U c already then say...
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
df.shape
# Out:
# (5573, 2)

# %%
#Independant Features
X=list(df['Message'])

# %%
#Dependant Features
y=list(df['Category'])

# %%
#Converting the Y into Weights
y=list(pd.get_dummies(y,drop_first=True)['spam'])
